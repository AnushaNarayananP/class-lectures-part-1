# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('C:\\Users\\LENOVO\\sales.csv')

# %%
df
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %%
df.head()
# Out:
#          Product_id  Stall_no             instock_date  Market_Category  \
# 0  BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1  TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2  BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3  WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4  JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
#
#   Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 0      Lillyann              Yes          Fashion      1      68
# 1         Klynn              Yes          Fashion      0      51
# 2         Ridge              Yes       Child_care      0      10
# 3         Abran              Yes      Educational      2      48
# 4        Dustyn              Yes           Repair      1      35
#
#    Discount_avail  charges_1  charges_2 (%)  Minimum_price  Maximum_price  \
# ...

# %%
df.tail()
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
#      Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 6363      Marquell              Yes       Technology      0      47
# 6364      Theodore              Yes       Child_care      0      35
# 6365         Galen              No            Repair      3      29
# 6366         Posey              Yes           Repair      0       8
# 6367        Cutler              Yes       Technology      0      94
#
#       Discount_avail  charges_1  charges_2 (%)  Minimum_price  Maximum_price  \
# ...

# %%
df.head(20)
# Out:
#           Product_id  Stall_no             instock_date  Market_Category  \
# 0   BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1   TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2   BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3   WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4   JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# 5   SHIECAYW3VZWGZGX      23.0  2015-09-25 16:31:46.000              162
# 6   SHOE4FZGGTE7HJXN      33.0  2014-12-08 12:25:52.000              462
# 7   SHOE6QGAYFFMBWG6       4.0  2015-09-22 14:29:06.000               23
# 8   KRTEBSMKCGFESHYX      26.0  2016-03-28 21:48:01.000              156
# 9   BRAE3P8Y8UVRY43K       5.0  2015-08-19 22:16:52.000              275
# 10  PTPE4JYT3DUYHFTM      16.0  2015-09-25 16:23:34.000                3
# 11  SUDEGGB5GCHTY53K       1.0  2016-03-29 20:00:39.000              268
# ...

# %%
df.tail(20)
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 6348  NKCE5XDEWDYXBG5G      31.0  2016-01-28 05:11:36.000               93
# 6349  PAEE8NDKFTPRKYMU      21.0  2016-03-27 23:52:13.000               90
# 6350  ACCDY6GYCSJ2UTHY      26.0  2016-03-21 02:56:19.000              211
# 6351  PTLEH3DFRABEVGNV      37.0  2015-09-13 20:17:07.000              128
# 6352  CAGE8PKGZJ5NFT7X      18.0  2016-01-04 08:06:03.000                3
# 6353  PTPE7GZXHWMQB5W8      45.0  2015-10-23 00:09:30.000              451
# 6354  PCSE76X4ZJWF88JD      18.0  2016-03-19 00:57:14.000              229
# 6355  BRAEBUHTTCZKDPTC      20.0  2015-08-20 02:32:24.000               65
# 6356  TOPDYAZZNRQMQABE      48.0  2015-08-23 18:48:47.000               68
# 6357  NKCE2F33KCCGEHRX      14.0  2015-12-05 02:55:13.000                3
# 6358  CAGDUGFYPRZUAJCM      40.0  2016-02-07 03:07:41.000              471
# ...

# %%
df.sample()
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 3630  TOPDWSEVDWZNKNCC      22.0  2015-05-06 14:19:02.000               14
#
#      Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 3630          Seth              No        Technology      0     100
#
#       Discount_avail  charges_1  charges_2 (%)  Minimum_price  Maximum_price  \
# 3630             0.0      563.0           11.0         3645.0         4769.0
#
#       Selling_Price
# 3630    4667.200825

# %%
df.sample(5)
# Out:
#             Product_id  Stall_no             instock_date  Market_Category  \
# 494   JCKEE7ZKPDVVEJ8T      16.0  2015-05-08 13:21:33.000              423
# 320   NKCDQSVCY7GJM39D      40.0  2015-11-16 23:45:29.000               63
# 541   PBXEBQGM9YPSQDMH      18.0  2016-02-20 22:39:21.000               39
# 5269  PCSECV3FERKHJPUT      36.0  2016-03-20 01:56:32.000              256
# 3109  NKCEBUG27RHUXNBY      41.0  2015-09-24 17:31:31.000               14
#
#      Customer_name Loyalty_customer Product_Category  Grade  Demand  \
# 494          Brock              Yes       Home_decor      0      48
# 320          Jayci              Yes          Fashion      1      88
# 541          Logen              Yes         Pet_care      3      98
# 5269       Kristyn              Yes       Child_care      0       7
# 3109        Kahlan              Yes      Hospitality      0      27
#
#       Discount_avail  charges_1  charges_2 (%)  Minimum_price  Maximum_price  \
# ...

# %%
df.describe()
# Out:
#           Stall_no  Market_Category        Grade       Demand  Discount_avail  \
# count  6363.000000      6368.000000  6368.000000  6368.000000     6330.000000
# mean     25.309445       199.340609     0.643687    50.921168        0.140442
# std      14.328980       170.275570     1.025092    29.091922        0.347473
# min       1.000000         0.000000     0.000000     1.000000        0.000000
# 25%      13.000000        55.000000     0.000000    26.000000        0.000000
# 50%      25.000000       132.000000     0.000000    51.000000        0.000000
# 75%      37.000000       403.000000     2.000000    76.000000        0.000000
# max      50.000000       471.000000     3.000000   100.000000        1.000000
#
#          charges_1  charges_2 (%)  Minimum_price  Maximum_price  Selling_Price
# count  6170.000000    6163.000000    6330.000000    6025.000000    6327.000000
# mean    264.514100      10.146195    3531.349763    6432.545892    4563.242592
# ...

# %%
df.shape
# Out:
# (6368, 15)

# %%
df.columns
# Out:
# Index(['Product_id', 'Stall_no', 'instock_date', 'Market_Category',
#        'Customer_name', 'Loyalty_customer', 'Product_Category', 'Grade',
#        'Demand', 'Discount_avail', 'charges_1', 'charges_2 (%)',
#        'Minimum_price', 'Maximum_price', 'Selling_Price'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Product_id           object
# Stall_no            float64
# instock_date         object
# Market_Category       int64
# Customer_name        object
# Loyalty_customer     object
# Product_Category     object
# Grade                 int64
# Demand                int64
# Discount_avail      float64
# charges_1           float64
# charges_2 (%)       float64
# Minimum_price       float64
# Maximum_price       float64
# Selling_Price       float64
# dtype: object

# %%
df.count()
# Out:
# Product_id          6368
# Stall_no            6363
# instock_date        6368
# Market_Category     6368
# Customer_name       6157
# Loyalty_customer    6368
# Product_Category    6368
# Grade               6368
# Demand              6368
# Discount_avail      6330
# charges_1           6170
# charges_2 (%)       6163
# Minimum_price       6330
# Maximum_price       6025
# Selling_Price       6327
# dtype: int64

# %%
df.median()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1064\530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# Stall_no             25.00000
# Market_Category     132.00000
# Grade                 0.00000
# Demand               51.00000
# Discount_avail        0.00000
# charges_1           252.00000
# charges_2 (%)        10.00000
# Minimum_price      3157.50000
# Maximum_price      5634.00000
# Selling_Price      4210.38464
# dtype: float64

# %%
df.std()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1064\3390915376.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.std()
# Stall_no             14.328980
# Market_Category     170.275570
# Grade                 1.025092
# Demand               29.091922
# Discount_avail        0.347473
# charges_1           124.483056
# charges_2 (%)         4.318339
# Minimum_price      2194.729604
# Maximum_price      3716.177364
# Selling_Price      2979.102408
# dtype: float64

# %%
df.mean()
# Out:
# C:\Users\LENOVO\AppData\Local\Temp\ipykernel_1064\3698961737.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.mean()
# Stall_no             25.309445
# Market_Category     199.340609
# Grade                 0.643687
# Demand               50.921168
# Discount_avail        0.140442
# charges_1           264.514100
# charges_2 (%)        10.146195
# Minimum_price      3531.349763
# Maximum_price      6432.545892
# Selling_Price      4563.242592
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_id        6368 non-null   object
#  1   Stall_no          6363 non-null   float64
#  2   instock_date      6368 non-null   object
#  3   Market_Category   6368 non-null   int64
#  4   Customer_name     6157 non-null   object
#  5   Loyalty_customer  6368 non-null   object
#  6   Product_Category  6368 non-null   object
#  7   Grade             6368 non-null   int64
#  8   Demand            6368 non-null   int64
#  9   Discount_avail    6330 non-null   float64
#  10  charges_1         6170 non-null   float64
#  11  charges_2 (%)     6163 non-null   float64
#  12  Minimum_price     6330 non-null   float64
#  13  Maximum_price     6025 non-null   float64
#  14  Selling_Price     6327 non-null   float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 746.4+ KB

# %%
df.info
# Out:
# <bound method DataFrame.info of             Product_id  Stall_no             instock_date  Market_Category  \
# 0     BRAE2NF6JA5GUEXG      37.0  2015-08-22 18:36:12.000                2
# 1     TUNE8SFB6RJN2HSD      38.0  2016-03-27 21:19:13.000               24
# 2     BRAEAR7WZPQGPBZU       9.0  2015-08-18 19:25:22.000              447
# 3     WATDZ2ZQ8JPDHCTJ      50.0  2016-03-28 21:53:01.000               23
# 4     JWSEBUKYQPMBZ3RK       7.0  2016-03-29 22:58:53.000               63
# ...                ...       ...                      ...              ...
# 6363  WATE7VE2D62VEKW8      17.0  2016-03-28 19:55:43.000               24
# 6364  SHOEF9G8Z4ZXF6WE      21.0  2015-02-11 15:09:26.000               55
# 6365  PBXEB9ZQ7HHCFXYG      36.0  2015-11-19 17:29:21.000              358
# 6366  NKCEAGXHRYTNTMG7      27.0  2015-12-08 04:19:33.000              452
# 6367  CAGE53FSAFWZRHFF      11.0  2016-01-20 19:45:35.000               58
#
# ...

# %%
c=df['Demand']
print(c)
# Out:
# 0       68
# 1       51
# 2       10
# 3       48
# 4       35
#         ..
# 6363    47
# 6364    35
# 6365    29
# 6366     8
# 6367    94
# Name: Demand, Length: 6368, dtype: int64

# %%
df.isnull().sum()
# Out:
# Product_id            0
# Stall_no              5
# instock_date          0
# Market_Category       0
# Customer_name       211
# Loyalty_customer      0
# Product_Category      0
# Grade                 0
# Demand                0
# Discount_avail       38
# charges_1           198
# charges_2 (%)       205
# Minimum_price        38
# Maximum_price       343
# Selling_Price        41
# dtype: int64

# %%
df.fillna(0,inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6368 entries, 0 to 6367
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Product_id        6368 non-null   object
#  1   Stall_no          6368 non-null   float64
#  2   instock_date      6368 non-null   object
#  3   Market_Category   6368 non-null   int64
#  4   Customer_name     6368 non-null   object
#  5   Loyalty_customer  6368 non-null   object
#  6   Product_Category  6368 non-null   object
#  7   Grade             6368 non-null   int64
#  8   Demand            6368 non-null   int64
#  9   Discount_avail    6368 non-null   float64
#  10  charges_1         6368 non-null   float64
#  11  charges_2 (%)     6368 non-null   float64
#  12  Minimum_price     6368 non-null   float64
#  13  Maximum_price     6368 non-null   float64
#  14  Selling_Price     6368 non-null   float64
# dtypes: float64(7), int64(3), object(5)
# memory usage: 746.4+ KB

# %% [markdown]
# df.dropna()

# %% [raw]
# boxplot

# %%
df.Demand.nunique()
# Out:
# 100

# %%
df.Demand.unique()
# Out:
# array([ 68,  51,  10,  48,  35,  49,  57,  67,  53,  84,   6,  22,  38,
#         39,  16,  74,  29,  56,   7,  72,  93,  81,   8,  80,  27,  44,
#         66,  23,  19,  85,  12,  61,  45,  40,  88,  71,  34,  31,  15,
#         55,  82,  46,  69,  14,  41,  60,  63,  87,  52,  28,  77,  21,
#         64,  95,  89,  32,  76,  73,  86,  70,  17,  75,  79,  43,  47,
#          9,   1,  91,   5,  65,  97,  94,  78,  90,  18,   2,  36,  50,
#         30,  58,  99,  24,  98,  96,  42,  25,  62,   4,  20,  59,  13,
#        100,  37,  92,  33,  83,  54,  26,  11,   3], dtype=int64)

# %%
df.duplicated(keep='last')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6363    False
# 6364    False
# 6365    False
# 6366    False
# 6367    False
# Length: 6368, dtype: bool

# %%
df['Demand'].unique()
# Out:
# array([ 68,  51,  10,  48,  35,  49,  57,  67,  53,  84,   6,  22,  38,
#         39,  16,  74,  29,  56,   7,  72,  93,  81,   8,  80,  27,  44,
#         66,  23,  19,  85,  12,  61,  45,  40,  88,  71,  34,  31,  15,
#         55,  82,  46,  69,  14,  41,  60,  63,  87,  52,  28,  77,  21,
#         64,  95,  89,  32,  76,  73,  86,  70,  17,  75,  79,  43,  47,
#          9,   1,  91,   5,  65,  97,  94,  78,  90,  18,   2,  36,  50,
#         30,  58,  99,  24,  98,  96,  42,  25,  62,   4,  20,  59,  13,
#        100,  37,  92,  33,  83,  54,  26,  11,   3], dtype=int64)

# %%
s1=pd.Series(np.random.rand(4))

# %%
s1
# Out:
# 0    0.730741
# 1    0.150341
# 2    0.349261
# 3    0.191376
# dtype: float64
